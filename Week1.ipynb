# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadroyyan11/PCVK_Genap_2021/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # image
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg","https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg","https://placekitten.com/800/777"]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276 at 0x7F4F51FDDA90>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F4F51FDDA90>
# <PIL.Image.Image image mode=RGB size=800x388 at 0x7F4F51A24290>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resollusi image: tinggi x lebar = ",tinggi, " x ",lebar)
cv2_imshow(image_2)
# Out:
# resollusi image: tinggi x lebar =  388  x  400
# <PIL.Image.Image image mode=RGB size=400x388 at 0x7F4F4F8AC1D0>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (lebar):
  image_3[int((tinggi)/2),y] = [0,0,0]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x388 at 0x7F4F4F899210>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

image_3 = cv.line(image, (0,0), (400,286), (255,255,255))
image_3 = cv.line(image, (400,0), (0,286), (255,255,255))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x388 at 0x7F4F4F8C2050>
