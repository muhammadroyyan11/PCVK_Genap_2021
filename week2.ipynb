# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadroyyan11/PCVK_Genap_2021/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)

# %%
plt.figure(figsize=(3,3))
plt.imshow(img3)

# %%
img4 = img3

img4[:,:,0] = np.zeros([img4.shape[0], img4.shape[1]])
plt.imshow(img4)

# %%
img5 = img3

img5[:,:,2] = np.zeros([img5.shape[0], img5.shape[1]])
plt.imshow(img5)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3[10:100, 10:100])

# %%
plt.imshow(img5[5:30])

# %%
import random

img6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
for x in range(6):
  startp = random.randint(0,250)
  endp = random.randint(0,250)

  c1 = random.randint(0,255)
  c2 = random.randint(0,255)
  c3 = random.randint(0,255)
  start_point = (startp , startp) 
    
  end_point = (endp, endp) 
    
  color = (c1, c2, c3) 
    
  thickness = 2
    
  img6 = cv.rectangle(img3, start_point, end_point, color, thickness) 
    
plt.imshow(img6)

# %%
img7 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

plt.imshow(img7)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE) 
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize = (10,10)) 
ax = fig.add_subplot(111) 
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(400,400), radius=50, color=(255,0,0), thickness=-2)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='hehe',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
#TUGAS
img99 = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')

fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111) 

cv.rectangle(img99,pt1=(25,125),pt2=(100,100),color=(0,255,0), thickness=2)

cv.circle(img99,center=(70,110),radius=50,color=(255,0,0),thickness=2)

ax.imshow(img99)

# %%
#Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!
#Tulis nama file pada file citra dari soal no.2. Gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.


img99 = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')

fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111) 

cv.rectangle(img99,pt1=(25,125),pt2=(100,100),color=(0,255,0), thickness=2)

cv.circle(img99,center=(70,110),radius=50,color=(255,0,0),thickness=2)

cv.rectangle(img99,pt1=(0,250),pt2=(110,225),color=(0,255,0), thickness=2)
cv.putText(img99, text='adams',org=(0,248),fontFace=font,fontScale=1,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)

ax.imshow(img99)
